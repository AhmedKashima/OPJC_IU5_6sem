# %% [markdown]
# # Обедающие философы (Threading version with timing)

# %%
import threading, random, time

class Filosoff(threading.Thread):
    running = True

    def __init__(self, xname, forkOne, forkTwo):
        super().__init__()
        self.name = xname
        self.forkOnLeft = forkOne
        self.forkOnRight = forkTwo
        self.f_eat_count = 0
        self.total_eating_time = 0
        self.last_eat_start = 0

    def run(self):
        while self.running:
            time.sleep(random.uniform(2,5))
            print(self.name, 'голодный.')
            self.dine()
        else:
            print(self.name, 'поел', self.f_eat_count, 'раз. Всего времени еды:', round(self.total_eating_time, 2), 'сек')
            return

    def dine(self):
        fork1, fork2 = self.forkOnLeft, self.forkOnRight

        while self.running:
            fork1.acquire(True)
            locked = fork2.acquire(False)
            if locked: break
            fork1.release()
            print(self.name, 'поменял порядок захвата.')
            fork1, fork2 = fork2, fork1
        else:
            return
            
        self.f_eat_count += 1
        print(self.name, 'начал есть.')
        self.last_eat_start = time.time()
        time.sleep(random.uniform(3,6))
        eating_duration = time.time() - self.last_eat_start
        self.total_eating_time += eating_duration
        print(self.name, 'наелся и думает. Ел', round(eating_duration, 2), 'сек')
        fork1.release()
        fork2.release()

# %%
def DiningFilosofs(numfilos):
    if (numfilos < 2) or (numfilos > 11):
       print('Число философов от 2 до 11!')
       return

    forks = [threading.Lock() for n in range(numfilos)]
    philosophNames = ('1:Кант:','2:Маркс:','3:Платон:','4:Руссо:','5:Сократ:',
                     '6:Пифагор:','7:Гегель:','8:Вольтер:','9:Декарт:',
                     '10:ЛаоЦзы:','11:Рассел:')
    
    philosophers = [Filosoff(philosophNames[i], forks[i%numfilos],
                   forks[(i+1)%numfilos]) for i in range(numfilos)]

    random.seed(1537)
    modelstart=time.perf_counter_ns()
    Filosoff.running = True
    for p in philosophers: p.start()
    time.sleep(40)
    Filosoff.running = False
    for p in philosophers: p.join()
    modelfini=time.perf_counter_ns()
    
    print("\n== Итоговые результаты ==")
    for p in philosophers:
        print(f"{p.name}: ел {p.f_eat_count} раз, общее время еды: {round(p.total_eating_time, 2)} сек")
    
    print("== Все закончили! Время =", (modelfini-modelstart)/1000000, "msec")

# %%
print("=== Тест с 3 философами ===")
DiningFilosofs(3)

print("\n=== Тест с 5 философами ===")
DiningFilosofs(5)

print("\n=== Тест с 10 философами ===")
DiningFilosofs(10)
# Out:
# === Тест с 3 философами ===
# 3:Платон: голодный.
# 3:Платон: начал есть.
# 1:Кант: голодный.
# 2:Маркс: голодный.
# 2:Маркс: поменял порядок захвата.
# 3:Платон: наелся и думает. Ел 4.39 сек
# 1:Кант: начал есть.
# 2:Маркс: поменял порядок захвата.
# 3:Платон: голодный.
# 3:Платон: поменял порядок захвата.
# 1:Кант: наелся и думает. Ел 5.73 сек
# 2:Маркс: начал есть.
# 3:Платон: поменял порядок захвата.
# 1:Кант: голодный.
# 1:Кант: поменял порядок захвата.
# 2:Маркс: наелся и думает. Ел 4.7 сек
# 3:Платон: начал есть.
# 1:Кант: поменял порядок захвата.
# 2:Маркс: голодный.
# 2:Маркс: поменял порядок захвата.
# 3:Платон: наелся и думает. Ел 5.46 сек
# 1:Кант: начал есть.
# 2:Маркс: поменял порядок захвата.
# 1:Кант: наелся и думает. Ел 3.64 сек
# 2:Маркс: начал есть.
# 3:Платон: голодный.
# 1:Кант: голодный.
# 1:Кант: поменял порядок захвата.
# 2:Маркс: наелся и думает. Ел 4.42 сек
# 1:Кант: начал есть.
# 3:Платон: поменял порядок захвата.
# 2:Маркс: голодный.
# 1:Кант: наелся и думает. Ел 4.62 сек
# 3:Платон: начал есть.
# 2:Маркс: поменял порядок захвата.
# 1:Кант: голодный.
# 3:Платон: наелся и думает. Ел 5.51 сек
# 3:Платон: поел 3 раз. Всего времени еды: 15.36 сек
# 2:Маркс: начал есть.
# 1:Кант: поменял порядок захвата.
# 1:Кант: поел 3 раз. Всего времени еды: 13.99 сек
# 2:Маркс: наелся и думает. Ел 5.1 сек
# 2:Маркс: поел 3 раз. Всего времени еды: 14.21 сек
#
# == Итоговые результаты ==
# 1:Кант:: ел 3 раз, общее время еды: 13.99 сек
# 2:Маркс:: ел 3 раз, общее время еды: 14.21 сек
# 3:Платон:: ел 3 раз, общее время еды: 15.36 сек
# == Все закончили! Время = 45625.338797 msec
#
# === Тест с 5 философами ===
# 3:Платон: голодный.
# 3:Платон: начал есть.
# 1:Кант: голодный.
# 1:Кант: начал есть.
# 4:Руссо: голодный.
# 2:Маркс: голодный.
# 5:Сократ: голодный.
# 5:Сократ: поменял порядок захвата.
# 3:Платон: наелся и думает. Ел 5.73 сек
# 4:Руссо: начал есть.
# 1:Кант: наелся и думает. Ел 5.48 сек
# 2:Маркс: начал есть.
# 5:Сократ: поменял порядок захвата.
# 3:Платон: голодный.
# 1:Кант: голодный.
# 1:Кант: поменял порядок захвата.
# 4:Руссо: наелся и думает. Ел 5.56 сек
# 5:Сократ: начал есть.
# 2:Маркс: наелся и думает. Ел 5.96 сек
# 1:Кант: поменял порядок захвата.
# 3:Платон: начал есть.
# 4:Руссо: голодный.
# 5:Сократ: наелся и думает. Ел 3.69 сек
# 1:Кант: начал есть.
# 2:Маркс: голодный.
# 3:Платон: наелся и думает. Ел 4.36 сек
# 4:Руссо: начал есть.
# 5:Сократ: голодный.
# 1:Кант: наелся и думает. Ел 5.62 сек
# 2:Маркс: начал есть.
# 3:Платон: голодный.
# 4:Руссо: наелся и думает. Ел 5.09 сек
# 5:Сократ: начал есть.
# 2:Маркс: наелся и думает. Ел 4.1 сек
# 3:Платон: начал есть.
# 1:Кант: голодный.
# 4:Руссо: голодный.
# 5:Сократ: наелся и думает. Ел 5.03 сек
# 1:Кант: начал есть.
# 2:Маркс: голодный.
# 5:Сократ: голодный.
# 5:Сократ: поменял порядок захвата.
# 3:Платон: наелся и думает. Ел 4.78 сек
# 4:Руссо: начал есть.
# 1:Кант: наелся и думает. Ел 4.26 сек
# 2:Маркс: начал есть.
# 5:Сократ: поменял порядок захвата.
# 3:Платон: голодный.
# 2:Маркс: наелся и думает. Ел 3.39 сек
# 3:Платон: поменял порядок захвата.
# 4:Руссо: наелся и думает. Ел 5.95 сек
# 3:Платон: начал есть.
# 5:Сократ: начал есть.
# 1:Кант: голодный.
# 4:Руссо: голодный.
# 4:Руссо: поел 3 раз. Всего времени еды: 16.6 сек
# 3:Платон: наелся и думает. Ел 3.65 сек
# 3:Платон: поел 4 раз. Всего времени еды: 18.52 сек
# 2:Маркс: голодный.
# 2:Маркс: поел 3 раз. Всего времени еды: 13.45 сек
# 5:Сократ: наелся и думает. Ел 4.49 сек
# 5:Сократ: поел 3 раз. Всего времени еды: 13.21 сек
# 1:Кант: начал есть.
# 1:Кант: наелся и думает. Ел 3.69 сек
# 1:Кант: поел 4 раз. Всего времени еды: 19.04 сек
#
# == Итоговые результаты ==
# 1:Кант:: ел 4 раз, общее время еды: 19.04 сек
# 2:Маркс:: ел 3 раз, общее время еды: 13.45 сек
# 3:Платон:: ел 4 раз, общее время еды: 18.52 сек
# 4:Руссо:: ел 3 раз, общее время еды: 16.6 сек
# 5:Сократ:: ел 3 раз, общее время еды: 13.21 сек
# == Все закончили! Время = 45662.400887 msec
#
# === Тест с 10 философами ===
# 3:Платон: голодный.
# 3:Платон: начал есть.
# 1:Кант: голодный.
# 1:Кант: начал есть.
# 4:Руссо: голодный.
# 2:Маркс: голодный.
# 5:Сократ: голодный.
# 5:Сократ: начал есть.
# 8:Вольтер: голодный.
# 8:Вольтер: начал есть.
# 10:ЛаоЦзы: голодный.
# 10:ЛаоЦзы: поменял порядок захвата.
# 7:Гегель: голодный.
# 7:Гегель: поменял порядок захвата.
# 9:Декарт: голодный.
# 6:Пифагор: голодный.
# 1:Кант: наелся и думает. Ел 3.64 сек
# 10:ЛаоЦзы: начал есть.
# 2:Маркс: поменял порядок захвата.
# 5:Сократ: наелся и думает. Ел 3.69 сек
# 6:Пифагор: начал есть.
# 3:Платон: наелся и думает. Ел 5.96 сек
# 4:Руссо: начал есть.
# 2:Маркс: начал есть.
# 8:Вольтер: наелся и думает. Ел 4.42 сек
# 9:Декарт: поменял порядок захвата.
# 7:Гегель: поменял порядок захвата.
# 1:Кант: голодный.
# 10:ЛаоЦзы: наелся и думает. Ел 4.62 сек
# 9:Декарт: начал есть.
# 1:Кант: поменял порядок захвата.
# 5:Сократ: голодный.
# 8:Вольтер: голодный.
# 8:Вольтер: поменял порядок захвата.
# 3:Платон: голодный.
# 2:Маркс: наелся и думает. Ел 4.1 сек
# 3:Платон: поменял порядок захвата.
# 1:Кант: начал есть.
# 6:Пифагор: наелся и думает. Ел 5.51 сек
# 7:Гегель: начал есть.
# 4:Руссо: наелся и думает. Ел 5.26 сек
# 5:Сократ: начал есть.
# 3:Платон: начал есть.
# 10:ЛаоЦзы: голодный.
# 1:Кант: наелся и думает. Ел 3.54 сек
# 2:Маркс: голодный.
# 2:Маркс: поменял порядок захвата.
# 9:Декарт: наелся и думает. Ел 4.66 сек
# 10:ЛаоЦзы: начал есть.
# 8:Вольтер: поменял порядок захвата.
# 6:Пифагор: голодный.
# 3:Платон: наелся и думает. Ел 3.39 сек
# 2:Маркс: начал есть.
# 7:Гегель: наелся и думает. Ел 4.51 сек
# 8:Вольтер: начал есть.
# 4:Руссо: голодный.
# 4:Руссо: поменял порядок захвата.
# 9:Декарт: голодный.
# 5:Сократ: наелся и думает. Ел 5.79 сек
# 6:Пифагор: начал есть.
# 4:Руссо: начал есть.
# 10:ЛаоЦзы: наелся и думает. Ел 3.65 сек
# 3:Платон: голодный.
# 1:Кант: голодный.
# 1:Кант: поменял порядок захвата.
# 2:Маркс: наелся и думает. Ел 3.69 сек
# 3:Платон: поменял порядок захвата.
# 1:Кант: начал есть.
# 7:Гегель: голодный.
# 6:Пифагор: наелся и думает. Ел 3.31 сек
# 7:Гегель: поменял порядок захвата.
# 5:Сократ: голодный.
# 8:Вольтер: наелся и думает. Ел 5.21 сек
# 9:Декарт: начал есть.
# 7:Гегель: начал есть.
# 10:ЛаоЦзы: голодный.
# 1:Кант: наелся и думает. Ел 3.53 сек
# 4:Руссо: наелся и думает. Ел 5.07 сек
# 3:Платон: начал есть.
# 5:Сократ: начал есть.
# 2:Маркс: голодный.
# 2:Маркс: поменял порядок захвата.
# 6:Пифагор: голодный.
# 4:Руссо: голодный.
# 1:Кант: голодный.
# 1:Кант: начал есть.
# 8:Вольтер: голодный.
# 7:Гегель: наелся и думает. Ел 5.07 сек
# 8:Вольтер: поменял порядок захвата.
# 9:Декарт: наелся и думает. Ел 5.76 сек
# 8:Вольтер: начал есть.
# 10:ЛаоЦзы: поменял порядок захвата.
# 3:Платон: наелся и думает. Ел 4.35 сек
# 4:Руссо: поменял порядок захвата.
# 2:Маркс: поменял порядок захвата.
# 5:Сократ: наелся и думает. Ел 4.73 сек
# 4:Руссо: начал есть.
# 6:Пифагор: начал есть.
# 7:Гегель: голодный.
# 9:Декарт: голодный.
# 3:Платон: голодный.
# 3:Платон: поменял порядок захвата.
# 1:Кант: наелся и думает. Ел 5.24 сек
# 10:ЛаоЦзы: начал есть.
# 2:Маркс: начал есть.
# 6:Пифагор: наелся и думает. Ел 3.68 сек
# 7:Гегель: поменял порядок захвата.
# 8:Вольтер: наелся и думает. Ел 4.81 сек
# 7:Гегель: начал есть.
# 9:Декарт: поменял порядок захвата.
# 5:Сократ: голодный.
# 4:Руссо: наелся и думает. Ел 5.83 сек
# 5:Сократ: начал есть.
# 3:Платон: поменял порядок захвата.
# 2:Маркс: наелся и думает. Ел 3.01 сек
# 3:Платон: начал есть.
# 1:Кант: голодный.
# 10:ЛаоЦзы: наелся и думает. Ел 3.75 сек
# 1:Кант: начал есть.
# 9:Декарт: начал есть.
# 8:Вольтер: голодный.
# 6:Пифагор: голодный.
# 7:Гегель: наелся и думает. Ел 4.59 сек
# 8:Вольтер: поменял порядок захвата.
# 5:Сократ: наелся и думает. Ел 3.39 сек
# 6:Пифагор: начал есть.
# 10:ЛаоЦзы: голодный.
# 2:Маркс: голодный.
# 3:Платон: наелся и думает. Ел 4.27 сек
# 4:Руссо: голодный.
# 4:Руссо: начал есть.
# 9:Декарт: наелся и думает. Ел 4.93 сек
# 9:Декарт: поел 3 раз. Всего времени еды: 15.36 сек
# 8:Вольтер: начал есть.
# 10:ЛаоЦзы: поменял порядок захвата.
# 10:ЛаоЦзы: поел 3 раз. Всего времени еды: 12.02 сек
# 1:Кант: наелся и думает. Ел 5.17 сек
# 1:Кант: поел 5 раз. Всего времени еды: 21.13 сек
# 2:Маркс: начал есть.
# 5:Сократ: голодный.
# 5:Сократ: поел 4 раз. Всего времени еды: 17.61 сек
# 7:Гегель: голодный.
# 7:Гегель: поел 3 раз. Всего времени еды: 14.17 сек
# 6:Пифагор: наелся и думает. Ел 3.92 сек
# 6:Пифагор: поел 4 раз. Всего времени еды: 16.42 сек
# 3:Платон: голодный.
# 3:Платон: поел 4 раз. Всего времени еды: 17.96 сек
# 4:Руссо: наелся и думает. Ел 4.23 сек
# 4:Руссо: поел 4 раз. Всего времени еды: 20.39 сек
# 8:Вольтер: наелся и думает. Ел 3.68 сек
# 8:Вольтер: поел 4 раз. Всего времени еды: 18.12 сек
# 2:Маркс: наелся и думает. Ел 5.32 сек
# 2:Маркс: поел 4 раз. Всего времени еды: 16.12 сек
#
# == Итоговые результаты ==
# 1:Кант:: ел 5 раз, общее время еды: 21.13 сек
# 2:Маркс:: ел 4 раз, общее время еды: 16.12 сек
# 3:Платон:: ел 4 раз, общее время еды: 17.96 сек
# 4:Руссо:: ел 4 раз, общее время еды: 20.39 сек
# 5:Сократ:: ел 4 раз, общее время еды: 17.61 сек
# 6:Пифагор:: ел 4 раз, общее время еды: 16.42 сек
# 7:Гегель:: ел 3 раз, общее время еды: 14.17 сек
# 8:Вольтер:: ел 4 раз, общее время еды: 18.12 сек
# 9:Декарт:: ел 3 раз, общее время еды: 15.36 сек
# 10:ЛаоЦзы:: ел 3 раз, общее время еды: 12.02 сек
# == Все закончили! Время = 45936.76712 msec

# %% [markdown]
# # Обедающие философы (Asyncio version with timing)

# %%
import asyncio, random, time

class AsyncFilosoff:
    def __init__(self, name, lockA, lockB):
        self.name = name
        self.lockA = lockA
        self.lockB = lockB
        self.eat_count = 0
        self.total_eating_time = 0
        
    async def run(self, running):
        while running[0]:
            await asyncio.sleep(random.uniform(2,5))
            print(self.name, 'голодный.')
            await self.dine(running)
        print(self.name, 'поел', self.eat_count, 'раз. Всего времени еды:', round(self.total_eating_time, 2), 'сек')
    
    async def dine(self, running):
        async with self.lockA:
            async with self.lockB:
                if not running[0]:
                    return
                self.eat_count += 1
                print(self.name, 'начал есть.')
                eat_time = random.uniform(3,6)
                start_time = time.time()
                await asyncio.sleep(eat_time)
                self.total_eating_time += time.time() - start_time
                print(self.name, 'наелся и думает. Ел', round(eat_time, 2), 'сек')

# %%
async def run_async_philosophers(numfilos):
    if (numfilos < 2) or (numfilos > 11):
        print('Число философов от 2 до 11!')
        return
    
    forks = [asyncio.Lock() for _ in range(numfilos)]
    philosophNames = ('1:Кант:','2:Маркс:','3:Платон:','4:Руссо:','5:Сократ:',
                     '6:Пифагор:','7:Гегель:','8:Вольтер:','9:Декарт:',
                     '10:ЛаоЦзы:','11:Рассел:')
    
    philosophers = [AsyncFilosoff(philosophNames[i], forks[i%numfilos],
                   forks[(i+1)%numfilos]) for i in range(numfilos)]
    
    running = [True]
    tasks = [philo.run(running) for philo in philosophers]
    
    modelstart = time.perf_counter_ns()
    await asyncio.sleep(40)
    running[0] = False
    
    await asyncio.gather(*tasks)
    modelfini = time.perf_counter_ns()
    
    print("\n== Итоговые результаты ==")
    for philo in philosophers:
        print(f"{philo.name}: ел {philo.eat_count} раз, общее время еды: {round(philo.total_eating_time, 2)} сек")
    
    print("== Все закончили! Время =", (modelfini-modelstart)/1000000, "msec")

# %%
print("=== Тест с 3 философами ===")
await run_async_philosophers(3)

print("\n=== Тест с 5 философами ===")
await run_async_philosophers(5)

print("\n=== Тест с 10 философами ===")
await run_async_philosophers(10)
# Out:
# === Тест с 3 философами ===
# 1:Кант: поел 0 раз. Всего времени еды: 0 сек
# 2:Маркс: поел 0 раз. Всего времени еды: 0 сек
# 3:Платон: поел 0 раз. Всего времени еды: 0 сек
#
# == Итоговые результаты ==
# 1:Кант:: ел 0 раз, общее время еды: 0 сек
# 2:Маркс:: ел 0 раз, общее время еды: 0 сек
# 3:Платон:: ел 0 раз, общее время еды: 0 сек
# == Все закончили! Время = 40043.197198 msec
#
# === Тест с 5 философами ===
# 1:Кант: поел 0 раз. Всего времени еды: 0 сек
# 2:Маркс: поел 0 раз. Всего времени еды: 0 сек
# 3:Платон: поел 0 раз. Всего времени еды: 0 сек
# 4:Руссо: поел 0 раз. Всего времени еды: 0 сек
# 5:Сократ: поел 0 раз. Всего времени еды: 0 сек
#
# == Итоговые результаты ==
# 1:Кант:: ел 0 раз, общее время еды: 0 сек
# 2:Маркс:: ел 0 раз, общее время еды: 0 сек
# 3:Платон:: ел 0 раз, общее время еды: 0 сек
# 4:Руссо:: ел 0 раз, общее время еды: 0 сек
# 5:Сократ:: ел 0 раз, общее время еды: 0 сек
# == Все закончили! Время = 40042.203053 msec
#
# === Тест с 10 философами ===
# 1:Кант: поел 0 раз. Всего времени еды: 0 сек
# 2:Маркс: поел 0 раз. Всего времени еды: 0 сек
# 3:Платон: поел 0 раз. Всего времени еды: 0 сек
# 4:Руссо: поел 0 раз. Всего времени еды: 0 сек
# 5:Сократ: поел 0 раз. Всего времени еды: 0 сек
# 6:Пифагор: поел 0 раз. Всего времени еды: 0 сек
# 7:Гегель: поел 0 раз. Всего времени еды: 0 сек
# 8:Вольтер: поел 0 раз. Всего времени еды: 0 сек
# 9:Декарт: поел 0 раз. Всего времени еды: 0 сек
# 10:ЛаоЦзы: поел 0 раз. Всего времени еды: 0 сек
#
# == Итоговые результаты ==
# 1:Кант:: ел 0 раз, общее время еды: 0 сек
# 2:Маркс:: ел 0 раз, общее время еды: 0 сек
# 3:Платон:: ел 0 раз, общее время еды: 0 сек
# 4:Руссо:: ел 0 раз, общее время еды: 0 сек
# 5:Сократ:: ел 0 раз, общее время еды: 0 сек
# 6:Пифагор:: ел 0 раз, общее время еды: 0 сек
# 7:Гегель:: ел 0 раз, общее время еды: 0 сек
# 8:Вольтер:: ел 0 раз, общее время еды: 0 сек
# 9:Декарт:: ел 0 раз, общее время еды: 0 сек
# 10:ЛаоЦзы:: ел 0 раз, общее время еды: 0 сек
# == Все закончили! Время = 40041.11599 msec
